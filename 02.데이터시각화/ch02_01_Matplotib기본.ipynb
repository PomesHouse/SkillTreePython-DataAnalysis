# %% [markdown]
# <a href="https://colab.research.google.com/github/PomesHouse/SkillTreePython-DataAnalysis/blob/main/02.%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%8B%9C%EA%B0%81%ED%99%94/ch02_01_Matplotib%EA%B8%B0%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ch02.01. Matplotlib 기본**
#
# ```
# 이 노트는 `Matplotlib Tutorial: 파이썬으로 데이터 시각화하기` 책을 바탕으로 공부하고 정리한 것임을 밝힙니다.
# ```
#
# * 책 소개
# >  [Matplotlib Tutorial: 파이썬으로 데이터 시각화하기](https://wikidocs.net/book/5011)
# >
#
#
# * 라이브러리 소개
#   > matplotlib

# %%
import numpy as np

# %% [markdown]
# ## **01. 기본 사용**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92071/basics_00.png width=500>
# </p>

# %% [markdown]
# ### **| 기본 그래프 그리기**
#
#
# ```
# import matplotlib.pyplot as plt
#
# plt.plot([1, 2, 3, 4])
# plt.show()
# ```

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4], marker = 'o' )

#plot() 함수는 리스트의 값들이 y 값들이라고 가정하고, x 값 [0, 1, 2, 3]을 자동으로 만들어냅니다.

# %% [markdown]
# ```
# plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()
#  x-y 값

# %% [markdown]
# ### **| 스타일 지정하기**
#
#
# ```
# plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
# plt.axis([0, 6, 0, 20])
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro') # ‘ro’는 빨간색 (‘red’)의 원형 (‘o’) 마커를 의미
#‘b-‘는 파란색 (‘blue’)의 실선 (‘-‘)을 의미
plt.axis([0, 6, 0, 20]) # [xmin, xmax, ymin, ymax]를 지정
plt.show()

# %% [markdown]
# ### **| 여러 개의 그래프 그리기**
#
#
# ```
# # 200ms 간격으로 균일하게 샘플된 시간
# t = np.arange(0., 5., 0.2)
#
# # 빨간 대쉬, 파란 사각형, 녹색 삼각형
# plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
# plt.show()
# ```

# %%
# 200ms 간격으로 균일하게 샘플된 시간
t = np.arange(0., 5., 0.2)

# 빨간 대쉬, 파란 사각형, 녹색 삼각형
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^', t, t**4, 'm:')
plt.show()

# %% [markdown]
# ## **02. 숫자 입력하기**
#
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/137321/basic_plot_00.png width=500>
# </p>

# %% [markdown]
# ### **| 기본 사용**
#
#
# ```
# import matplotlib.pyplot as plt
#
# plt.plot([2, 3, 5, 10])
# plt.show()
# ```

# %%
plt.plot([2, 3, 5, 10]) #  하나의 리스트 형태로 값들을 입력하면 y 값으로 인식합니다.
plt.show()

# %% [markdown]
# ### **| x, y 값 입력**
#
#
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
# plt.show()
# ```

# %%
plt.plot([1,2,3,4],[2,3,5,10])
plt.show()

# %% [markdown]
# ### **| 레이블이 있는 데이터 사용하기**
#
#
#
#
# ```
# data_dict = {'data_x': [1, 2, 3, 4, 5], 'data_y': [2, 3, 5, 10, 8]}
#
# plt.plot('data_x', 'data_y', data=data_dict)
# plt.show()
# ```

# %%
data_dict = {'data_x':[1,2,3,4,5], 'data_y': [2,3,5,10,8]}
plt.plot('data_x', 'data_y', data = data_dict)
plt.show()

# 파이썬 딕셔너리와 같이 레이블이 있는 데이터를 그래프로 나타낼 수 있다.
# 먼저 plot() 함수에 데이터의 레이블 (딕셔너리의 키)을 입력해주고,
# data 파라미터에 딕셔너리를 지정해줍니다.

# %% [markdown]
# ## **03. 축 레이블 설정하기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92081/set_label_00.png width=500>
# </p>

# %% [markdown]
# ### **| 기본 사용**
#
#
# ```
# import matplotlib.pyplot as plt
#
# plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
# plt.xlabel('X-Label')
# plt.ylabel('Y-Label')
# plt.show()
# ```

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.xlabel('X-Label')
plt.ylabel('Y-Label')
plt.show()

# %% [markdown]
# ### **| 여백 지정**
#
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
# plt.xlabel('X-Axis', labelpad=15)
# plt.ylabel('Y-Axis', labelpad=20)
# plt.show()
# ```

# %%
plt.plot([1,2,3,4],[2,3,5,10])
plt.xlabel('X-Axis', labelpad = 15)
plt.ylabel('Y-Axis', labelpad = 20)
plt.show()

# %% [markdown]
# ### **| 폰트 설정하기**
#
#
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
# plt.xlabel('X-Axis', labelpad=15, fontdict={'family': 'serif', 'color': 'b', 'weight': 'bold', 'size': 14})
# plt.ylabel('Y-Axis', labelpad=20, fontdict={'family': 'fantasy', 'color': 'deeppink', 'weight': 'normal', 'size': 'xx-large'})
# plt.show()
# ```

# %%
plt.plot([1,2,3,4],[2,3,5,10])
plt.xlabel('X-Axis', labelpad = 15, fontdict = {'family':'serif', 'color':'b','weight':'bold','size':14})
plt.ylabel('Y-Axis', labelpad=20, fontdict={'family': 'fantasy', 'color': 'deeppink', 'weight': 'normal', 'size': 'xx-large'})
# xlabel(), ylabel() 함수의 fontdict 파라미터를 사용하면 축 레이블의 폰트 스타일을 설정할 수 있습니다.
plt.show()

# %% [markdown]
# ```
# font1 = {'family': 'serif',
#          'color': 'b',
#          'weight': 'bold',
#          'size': 14
#          }
#
# font2 = {'family': 'fantasy',
#          'color': 'deeppink',
#          'weight': 'normal',
#          'size': 'xx-large'
#          }
#
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
# plt.xlabel('X-Axis', labelpad=15, fontdict=font1)
# plt.ylabel('Y-Axis', labelpad=20, fontdict=font2)
# plt.show()
# ```

# %%
font1 = {'family': 'serif',
         'color': 'b',
         'weight': 'bold',
         'size': 14
         }

font2 = {'family': 'fantasy',
         'color': 'deeppink',
         'weight': 'normal',
         'size': 'xx-large'
         }
plt.plot([1,2,3,4],[2,3,5,10])
plt.xlabel('X-Axis', labelpad = 15, fontdict = font1)
plt.ylabel('Y_Axis', labelpad = 20, fontdict = font2)
plt.show()

# %% [markdown]
# ### **| 위치 지정하기**
#
#
# `xlabel()` 함수의 `loc` 파라미터는 X축 레이블의 위치를 지정합니다. `({‘left’, ‘center’, ‘right’})`
#
# `ylabel()` 함수의 `loc` 파라미터는 Y축 레이블의 위치를 지정합니다. `({‘bottom’, ‘center’, ‘top’})`
#
#
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
# plt.xlabel('X-Axis', loc='right')
# plt.ylabel('Y-Axis', loc='top')
# plt.show()
# ```

# %%
# 버전이 달라서 pass

# %% [markdown]
# ## **04. 범례 표시하기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/137778/set_legend_00.png width=500>
# </p>

# %% [markdown]
# ### **| 기본 사용**
#
# ```
# import matplotlib.pyplot as plt
#
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.legend()
#
# plt.show()
# ```

# %%
# 범례 (Legend)는 그래프에 데이터의 종류를 표시하기 위한 텍스트입니다.
plt.plot([1,2,3,4],[2,3,5,10], label = 'Price ($)')
plt.xlabel('X-Axis', labelpad = 15, fontdict = font1)
plt.ylabel('Y-Axis', labelpad = 20, fontdict = font2)
plt.legend()
plt.show()
# 그래프의 적절한 위치에 데이터를 설명하는 범례가 나타납니다.

# %% [markdown]
# ### **| 위치 지정하기**
#
#
#
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# # plt.legend(loc=(0.0, 0.0))
# # plt.legend(loc=(0.5, 0.5))
# plt.legend(loc=(1.0, 1.0))
#
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
#plt.legend(loc=(0.0, 0.0))
# plt.legend(loc=(0.5, 0.5))
plt.legend(loc=(1.0, 1.0))

# legend() 함수의 loc 파라미터를 이용해서 범례가 표시될 위치를 설정할 수 있습니다.
# loc 파라미터를 숫자 쌍 튜플로 지정하면, 해당하는 위치에 범례가 표시됩니다.
# loc=(0.0, 0.0)은 데이터 영역의 왼쪽 아래, loc=(1.0, 1.0)은 데이터 영역의 오른쪽 위 위치입니다.
plt.show()

# %% [markdown]
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.legend(loc='lower right')
#
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend(loc='lower right')

plt.show()

# %% [markdown]
# ### **| 열 개수 지정하기**
#
#
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
# plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# # plt.legend(loc='best')          # ncol = 1
# plt.legend(loc='best', ncol=2)    # ncol = 2
#
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.legend(loc='best')          # ncol = 1 (기본)
plt.legend(loc='best', ncol=2)    # ncol = 2
# legend() 함수의 ncol 파라미터는 범례에 표시될 텍스트의 열의 개수를 지정합니다.
plt.show()

# %% [markdown]
# ### **| 폰트 크기 지정하기**
#
#
#
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
# plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# # plt.legend(loc='best')
# plt.legend(loc='best', ncol=2, fontsize=14)
#
# plt.show()
# ```

# %%
plt.plot([1,2,3,4],[2,3,5,10], label = 'Price ($)')
plt.plot([1,2,3,4],[3,5,9,7], label = 'Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.legend(loc='best')
plt.legend(loc='best', ncol=2, fontsize = 14)
plt.show()

# %% [markdown]
# ### **| 범례 테두리 꾸미기**
#
#
#
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
# plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# # plt.legend(loc='best')
# plt.legend(loc='best', ncol=2, fontsize=14, frameon=True, shadow=True)
#
# plt.show()
# ```

# %%
font1
# Out:
# {'color': 'b', 'family': 'serif', 'size': 14, 'weight': 'bold'}

# %%
plt.plot([1,2,3,4],[2,3,5,10], label = 'Price ($)')
plt.plot([1,2,3,4],[3,5,9,7], label = 'Demand (#)')
plt.xlabel('X-Axis', labelpad = 15, color = 'navy', size = 14, weight =  'bold', family = 'Fantasy') # 이렇게 풀어써도 가능하다. 
plt.ylabel('Y-Axis', labelpad = 20, fontdict = font2)
plt.legend(loc = 'best', ncol = 2, frameon = True, shadow = True)
plt.show()

# 이 외, legend() 함수에는 facecolor, edgecolor, borderpad, labelspacing과 같은 다양한 파라미터가 존재.

# %% [markdown]
# ## **05. 축 범위 지정하기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92082/axis_range_00.png width=500>
# </p>

# %% [markdown]
# ### **| 기본 사용 - `xlim(), ylim()`**
#
#
#
# ```
# import matplotlib.pyplot as plt
#
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.xlim([0, 5])      # X축의 범위: [xmin, xmax]
# plt.ylim([0, 20])     # Y축의 범위: [ymin, ymax]
#
# plt.show()
# ```

# %%
plt.plot([1,2,3,4],[2,3,5,10], label = 'Poxis height')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend( loc ='best', frameon = True, shadow = False)
plt.xlim([0,5]) # tuple, list 등으로 묶어주어도 되지만, 안 묶어주어도 된다. 
plt.ylim(0,20)
plt.show()

# %% [markdown]
# ### **| 기본 사용: `axis()`**
#
#
#
#
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.axis([0, 5, 0, 20])  # X, Y축의 범위: [xmin, xmax, ymin, ymax]
#
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0, 5, 0, 20])  # X, Y축의 범위: [xmin, xmax, ymin, ymax]

# axis() 함수에 입력한 리스트 (또는 튜플)는 반드시 네 개의 값 (xmin, xmax, ymin, ymax)이 있어야 합니다.
# 입력값이 없으면 데이터에 맞게 자동으로 범위를 지정합니다.

plt.show()

# %% [markdown]
# ### **| 옵션 지정하기**
#
# ```
# 'on' | 'off' | 'equal' | 'scaled' | 'tight' | 'auto' | 'normal' | 'image' | 'square'
# ```
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# # plt.axis('square')
# plt.axis('scaled')
#
# plt.show()
# ```

# %%
# 'on' | 'off' | 'equal' | 'scaled' | 'tight' | 'auto' | 'normal' | 'image' | 'square'
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.axis('square') # 축의 길이가 동일하게 표시됨
plt.axis('scaled')  # x, y축이 같은 길이 스케일로 나타난다. 

plt.show()

# %% [markdown]
# ### **| 축 범위 얻기**
#
#
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
#
# x_range, y_range = plt.xlim(), plt.ylim()
# print(x_range, y_range)
#
# axis_range = plt.axis('scaled')
# print(axis_range)
#
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

x_range, y_range = plt.xlim(), plt.ylim() 
# xlim(), ylim() 함수는 그래프 영역에 표시되는 X축, Y축의 범위를 각각 반환합니다.
print(x_range, y_range)

axis_range = plt.axis('scaled')
# 안에 'scaled' 나 'square' 등의 옵션에 따라서 나오는 값이 달라진다. 
# axis() 함수는 그래프 영역에 표시되는 X, Y축의 범위를 반환합니다.
print(axis_range)

plt.show()
# Out:
# (0.85, 4.15) (1.6, 10.4)
# (0.85, 4.15, 1.6, 10.4)

# %% [markdown]
# ## **06. 선 종류 지정하기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/137791/set_linestyle_00.png width=500>
# </p>

# %% [markdown]
# ### **| 기본 사용**
#
#
# | 표현 | 종류 |
# |--|--|
# |`-`  | Solid |
# | `--` |Dashed|
# |`:`|Dotted|
# |`-.` |Dash-dot|
#
# ```
# import matplotlib.pyplot as plt
#
# plt.plot([1, 2, 3], [4, 4, 4], '-', color='C0', label='Solid')
# plt.plot([1, 2, 3], [3, 3, 3], '--', color='C0', label='Dashed')
# plt.plot([1, 2, 3], [2, 2, 2], ':', color='C0', label='Dotted')
# plt.plot([1, 2, 3], [1, 1, 1], '-.', color='C0', label='Dash-dot')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.axis([0.8, 3.2, 0.5, 5.0])
# plt.legend(loc='upper right', ncol=4)
# plt.show()
# ```

# %%
plt.plot([1,2,3],[4,4,4], '-', color = 'C0', label = 'Solid')
plt.plot([1,2,3],[3,3,3], '--', color = 'C0', label = 'Dashed')
plt.plot([1,2,3],[2,2,2], ':', color = 'C0', label = 'Dotted')
plt.plot([1,2,3],[1,1,1], '-.', color = 'C0', label = 'Dash-dot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend(loc = 'best', ncol = 4)
plt.axis([0, 4, 0, 5])
plt.show()

# %% [markdown]
# ### **| linestyle 지정하기**
#
#
# | 표현 | 종류 |
# |--|--|
# |`solid`  | Solid |
# | `dashed` |Dashed|
# |`dotted`|Dotted|
# |`dashdot` | Dash-dot|
#
# ```
# plt.plot([1, 2, 3], [4, 4, 4], linestyle='solid', color='C0', label="'solid'")
# plt.plot([1, 2, 3], [3, 3, 3], linestyle='dashed', color='C0', label="'dashed'")
# plt.plot([1, 2, 3], [2, 2, 2], linestyle='dotted', color='C0', label="'dotted'")
# plt.plot([1, 2, 3], [1, 1, 1], linestyle='dashdot', color='C0', label="'dashdot'")
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.axis([0.8, 3.2, 0.5, 5.0])
# plt.legend(loc='upper right', ncol=4)
# plt.tight_layout()
# plt.show()
# ```

# %%
plt.plot([1, 2, 3], [4, 4, 4], linestyle='solid', color='C0', label="'solid'")
plt.plot([1, 2, 3], [3, 3, 3], linestyle='dashed', color='C0', label="'dashed'")
plt.plot([1, 2, 3], [2, 2, 2], linestyle='dotted', color='C0', label="'dotted'")
plt.plot([1, 2, 3], [1, 1, 1], linestyle='dashdot', color='C0', label="'dashdot'")
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=4)
plt.tight_layout()
# 이 함수는 자동으로 명시된 여백(padding)에 관련된 서브플롯 파라미터를 조정한다. 
# 이 함수에서의 모든 키워드 인자는 선택적으로 입력 가능하다. 
# 입력 없이 사용할 경우 기존에 세팅된 기본값을 이용하여 자동으로 레이아웃을 설정한다.
plt.show()

# %% [markdown]
# ### **| 튜플 사용하기**
#
#
# ```
# plt.plot([1, 2, 3], [4, 4, 4], linestyle=(0, (1, 1)), color='C0', label='(0, (1, 1))')
# plt.plot([1, 2, 3], [3, 3, 3], linestyle=(0, (1, 5)), color='C0', label='(0, (1, 5))')
# plt.plot([1, 2, 3], [2, 2, 2], linestyle=(0, (5, 1)), color='C0', label='(0, (5, 1))')
# plt.plot([1, 2, 3], [1, 1, 1], linestyle=(0, (3, 5, 1, 5)), color='C0', label='(0, (3, 5, 1, 5))')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.axis([0.8, 3.2, 0.5, 5.0])
# plt.legend(loc='upper right', ncol=2)
# plt.tight_layout()
# plt.show()
# ```

# %%
plt.plot([1, 2, 3], [4, 4, 4], linestyle=(0, (1, 1)), color='C0', label='(0, (1, 1))')
plt.plot([1, 2, 3], [3, 3, 3], linestyle=(0, (1, 5)), color='C0', label='(0, (1, 5))')
plt.plot([1, 2, 3], [2, 2, 2], linestyle=(0, (5, 1)), color='C0', label='(0, (5, 1))')
plt.plot([1, 2, 3], [1, 1, 1], linestyle=(0, (3, 5, 1, 5)), color='C0', label='(0, (3, 5, 1, 5))')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=2)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **| 선 끝 모양 지정하기**
#
#
#
#
#
# ```
# import matplotlib.pyplot as plt
#
# plt.plot([1, 2, 3], [4, 4, 4], linestyle='solid', linewidth=10,
#       solid_capstyle='butt', color='C0', label='solid+butt')
# plt.plot([1, 2, 3], [3, 3, 3], linestyle='solid', linewidth=10,
#       solid_capstyle='round', color='C0', label='solid+round')
#
# plt.plot([1, 2, 3], [2, 2, 2], linestyle='dashed', linewidth=10,
#       dash_capstyle='butt', color='C1', label='dashed+butt')
# plt.plot([1, 2, 3], [1, 1, 1], linestyle='dashed', linewidth=10,
#       dash_capstyle='round', color='C1', label='dashed+round')
#
#
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.axis([0.8, 3.2, 0.5, 5.0])
# plt.legend(loc='upper right', ncol=2)
# plt.tight_layout()
# plt.show()
# ```

# %%
plt.plot([1, 2, 3], [4, 4, 4], linestyle='solid', linewidth=10,
      solid_capstyle='butt', color='C0', label='solid+butt')
plt.plot([1, 2, 3], [3, 3, 3], linestyle='solid', linewidth=10,
      solid_capstyle='round', color='C0', label='solid+round')

plt.plot([1, 2, 3], [2, 2, 2], linestyle='dashed', linewidth=10,
      dash_capstyle='butt', color='C1', label='dashed+butt')
plt.plot([1, 2, 3], [1, 1, 1], linestyle='dashed', linewidth=10,
      dash_capstyle='round', color='C1', label='dashed+round')


plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=2)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **07. 마커 지정하기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92083/set_marker_00.png width=500>
# </p>

# %% [markdown]
# ### **| 기본 사용**
#
#
# ```
# import matplotlib.pyplot as plt
#
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'r^:')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %% [markdown]
# ### **| 선/마커 동시에 나타내기**
#
#
# ```
# # plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo-')    # 파란색 + 마커 + 실선
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo--')     # 파란색 + 마커 + 점선
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.show()
# ```

# %%
plt.plot([1,2,3,4],[2,3,5,10], 'bo--')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %% [markdown]
# ### **| 선/마커 표시 형식**
#
# | 표현 | 종류 |
# |--|--|
# |`b`  | blue markers with default shape |
# | `ro` |red circles|
# |`g-`|green solid line|
# |`k^` | balck triangle_up markers connected by a dotted line|
#
#
# ```
# # plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo-')    # 파란색 + 마커 + 실선
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo--')     # 파란색 + 마커 + 점선
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'c*-')    
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %% [markdown]
# ### **| marker 파라미터 사용하기**
#
# ```
# plt.plot([4, 5, 6], marker="H")
# plt.plot([3, 4, 5], marker="d")
# plt.plot([2, 3, 4], marker="x")
# plt.plot([1, 2, 3], marker=11)
# plt.plot([0, 1, 2], marker='$Z$')
# plt.show()
# ```

# %%
plt.plot([4, 5, 6], "H")
plt.plot([3, 4, 5], marker="d")
plt.plot([2, 3, 4], marker="x")
plt.plot([1, 2, 3], marker=11)
plt.plot([0, 1, 2], marker='$L$')
plt.show()

# %% [markdown]
# ---
# ## **08. 색상 지정하기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92085/set_color_00.png width=500>
# </p>

# %% [markdown]
# ### **| 포맷 문자열 사용하기**
#
#
# ```
# import matplotlib.pyplot as plt
#
# plt.plot([1, 2, 3, 4], [2.0, 3.0, 5.0, 10.0], 'r')
# plt.plot([1, 2, 3, 4], [2.0, 2.8, 4.3, 6.5], 'g')
# plt.plot([1, 2, 3, 4], [2.0, 2.5, 3.3, 4.5], 'b')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
#
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2.0, 3.0, 5.0, 10.0], 'r')
plt.plot([1, 2, 3, 4], [2.0, 2.8, 4.3, 6.5], 'g')
plt.plot([1, 2, 3, 4], [2.0, 2.5, 3.3, 4.5], 'b')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.show()

# %% [markdown]
# ### **| `color` 키워드 인자 사용하기**
#
#
# ```
# plt.plot([1, 2, 3, 4], [2.0, 3.0, 5.0, 10.0], color='limegreen')
# plt.plot([1, 2, 3, 4], [2.0, 2.8, 4.3, 6.5], color='violet')
# plt.plot([1, 2, 3, 4], [2.0, 2.5, 3.3, 4.5], color='dodgerblue')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
#
# plt.show()
# ```

# %%
# color 키워드 인자를 사용해서 더 다양한 색상의 이름을 지정할 수 있습니다.
# plot() 함수에 color=’limegreen’과 같이 입력하면, limegreen에 해당하는 색깔이 표시됩니다.

plt.plot([1, 2, 3, 4], [2.0, 3.0, 5.0, 10.0], color='limegreen')
plt.plot([1, 2, 3, 4], [2.0, 2.8, 4.3, 6.5], color='violet')
plt.plot([1, 2, 3, 4], [2.0, 2.5, 3.3, 4.5], color='dodgerblue')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.show()

# %% [markdown]
# ### **| Hex code 사용하기**
#
#
#
#
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], color='#e35f62',
#          marker='o', linestyle='--')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
#
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], color='#e35f62',
         marker='o', linestyle='--')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.show()

# %% [markdown]
# ### **| Matplotlib 색상들**

# %% [markdown]
# * **Cycler 색상**
#
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92085/set_color_06.png width=300>
# </p>

# %% [markdown]
# * **기본 색상**
#
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92085/set_color_04.PNG width=500>
# </p>

# %% [markdown]
# * **Tableau 색상**
#
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92085/set_color_07.PNG width=450>
# </p>

# %% [markdown]
# * **CSS 색상**
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92085/set_color_05.PNG width=550>
# </p>

# %% [markdown]
# ## **09. 그래프 영역 채우기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92086/fill_region_00.png width=500>
# </p>

# %% [markdown]
# ### **| 기본 사용 - fill_between()**
#
#
# ```
# import matplotlib.pyplot as plt
#
# x = [1, 2, 3, 4]
# y = [2, 3, 5, 10]
#
# plt.plot(x, y)
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.fill_between(x[1:3], y[1:3], alpha=0.5)
#
# plt.show()
# ```

# %%
x = [1, 2, 3, 4]
y = [2, 3, 5, 10]

plt.plot(x, y)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.fill_between(x[1:3], y[1:3], alpha=0.5)

plt.show()

# fill_between() - 두 수평 방향의 곡선 사이를 채웁니다.
# fill_betweenx() - 두 수직 방방의 곡선 사이를 채웁니다.
# fill() - 다각형 영역을 채웁니다.

# %% [markdown]
# ### **| 기본 사용 - fill_betweenx()**
#
#
#
# ```
# x = [1, 2, 3, 4]
# y = [2, 3, 5, 10]
#
# plt.plot(x, y)
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.fill_betweenx(y[2:4], x[2:4], alpha=0.5)
#
# plt.show()
# ```

# %%
x = [1, 2, 3, 4]
y = [2, 3, 5, 10]

plt.plot(x, y)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.fill_betweenx(y[2:4], x[2:4], alpha=0.5)

plt.show()

# %% [markdown]
# ### **| 두 그래프 사이 영역 채우기**
#
#
# ```
# x = [1, 2, 3, 4]
# y1 = [2, 3, 5, 10]
# y2 = [1, 2, 4, 8]
#
# plt.plot(x, y1)
# plt.plot(x, y2)
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.fill_between(x[1:3], y1[1:3], y2[1:3], color='lightgray', alpha=0.5)
#
# plt.show()
# ```

# %%
x = [1, 2, 3, 4]
y1 = [2, 3, 5, 10]
y2 = [1, 2, 4, 8]

plt.plot(x, y1)
plt.plot(x, y2)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.fill_between(x[1:3], y1[1:3], y2[1:3], color = 'lightgray', alpha = 0.5)
plt.show()

# %%
x = [1, 2, 3, 4]
y1 = [2, 3, 5, 10]
y2 = [1, 2, 4, 8]
plt.plot(x, y1)
plt.plot(x, y2)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.fill_between(y2[1:3], x[1:3],y1[1:3], color = 'lightgray', alpha = 0.5)
plt.show()

# %% [markdown]
# ### **| 다각형 영역 채우기 - fill()**
#
# ```
# x = [1, 2, 3, 4]
# y1 = [2, 3, 5, 10]
# y2 = [1, 2, 4, 8]
#
# plt.plot(x, y1)
# plt.plot(x, y2)
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.fill([1.9, 1.9, 3.1, 3.1], [1.0, 4.0, 6.0, 3.0], color='lightgray', alpha=0.5)
#
# plt.show()
# ```

# %%
x = [1, 2, 3, 4]
y1 = [2, 3, 5, 10]
y2 = [1, 2, 4, 8]

plt.plot(x, y1)
plt.plot(x, y2)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.fill([1.9, 1.9, 3.1, 3.1], [1.0, 4.0, 6.0, 3.0], color='lightgray', alpha=0.5)
# fill() 함수에 [x], [y] 값의 리스트를 입력해주면,
# 각 x, y 점들로 정의되는 다각형 영역을 자유롭게 지정해서 채울 수 있습니다.

plt.show()

# %% [markdown]
# ## **10. 축 스케일 지정하기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/137913/axis_scale_00.png width=500>
# </p>

# %% [markdown]
# ### **| X축 스케일 지정하기**
#
#
# ```
# import matplotlib.pyplot as plt
# import numpy as np
#
# x = np.linspace(-10, 10, 100)
# y = x ** 3
#
# plt.plot(x, y)
# plt.xscale('symlog')
#
# plt.show()
# ```

# %%
# xscale(), yscale() 함수를 사용해서 그래프의 축 스케일을 다양하게 지정할 수 있습니다.
# 축은 기본적으로 ‘linear’ 스케일로 표시되지만 ‘log’, ‘symlog’, ‘logit’으로 변경할 수 있습니다.

x = np.linspace(-10, 10, 100) # -10에서 10까지 100개의 요소로 만들어라 
y = x ** 3

plt.plot(x, y)
plt.xscale('symlog') # symlog = Symmetrical Log Scale
# 축의 원점을 기준으로 양, 음의 방향이 대칭적인 로그 스케일로 표시됩니다.

plt.show()

# %% [markdown]
# ### **| Y축 스케일 지정하기**
#
# ```
# x = np.linspace(0, 5, 100)
# y = np.exp(x)
#
# plt.plot(x, y)
# # plt.yscale('linear')
# plt.yscale('log')
#
# plt.show()
# ```

# %%
x  = np.linspace(0,5,100)
y = np.exp(x)


plt.plot(x,y)
# plt.yscale('linear')
plt.yscale('log')
# 로그 스케일은 지수함수 (Exponential function)와 같이 기하급수적으로 변화하는 데이터를 표현하기에 적합합니다.

plt.show()

# %% [markdown]
# ## **11. 여러 곡선 그리기**
#
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92087/multiple_curves_00.png width=500>
# </p>

# %% [markdown]
# ### **| 기본사용**
#
#
#
# ```
# import matplotlib.pyplot as plt
# import numpy as np
#
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'r--', x, x**2, 'bo', x, x**3, 'g-.')
# plt.show()
# ```

# %%
x = np.arange(0, 2, 0.2)
plt.plot(x, x, 'r--', x, x**2, 'bo', x, x**3, 'g-.')
plt.show()

# %% [markdown]
# ### **| 스타일 지정하기**
#
#
# ```
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'bo')
# plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
# plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
# plt.show()
# ```

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2, markersize = 9)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
plt.show()

# %% [markdown]
# ## **12. 그리드 설정하기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92088/set_grid_00.png width=500>
# </p>

# %% [markdown]
# ### **| 기본사용**
#
# ```
# import matplotlib.pyplot as plt
# import numpy as np
#
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'bo')
# plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
# plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
# plt.grid(True)
#
# plt.show()
# ```

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
plt.grid()

plt.show()

# %% [markdown]
# ### **| 축 지정하기**
#
#
#
#
# ```
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'bo')
# plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
# plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
# plt.grid(True, axis='y')
#
# plt.show()
# ```

# %%
plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
plt.grid(axis = 'y')
# {‘both’, ‘x’, ‘y’} 중 선택할 수 있고 디폴트는 ‘both’입니다.
plt.show()

# %% [markdown]
# ### **| 스타일 설정하기**
#
#
# ```
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'bo')
# plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
# plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
# plt.grid(True, axis='y', color='red', alpha=0.5, linestyle='--')
#
# plt.show()
# ```

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
plt.grid(True, axis = 'y', color = 'm', alpha= 0.5, linestyle = '--', linewidth = 5, which = 'both')
plt.show()

#color, alpha, linestyle 파마리터를 사용해서 그리드 선의 스타일을 설정했습니다.
# 또한 which 파라미터를 ‘major’, ‘minor’, ‘both’ 등으로 사용하면 
# 주눈금, 보조눈금에 각각 그리드를 표시할 수 있습니다.

# %% [markdown]
# ## **13. 눈금 표시하기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92089/set_ticks_00.png width=500>
# </p>

# %% [markdown]
# ### **| 기본사용**
#
#
# ```
# import numpy as np
#
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'bo')
# plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
# plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
# plt.xticks([0, 1, 2])
# plt.yticks(np.arange(1, 6))
#
# plt.show()
# ```

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
plt.xticks([0, 1, 2])
plt.yticks(np.arange(1, 6))
# xticks(), yticks() 함수에 파이썬 리스트 또는 NumPy 어레이를 입력하면 눈금과 숫자 레이블이 표시됩니다.
plt.show()

# %% [markdown]
# ### **| 눈금 레이블 지정하기**
#
#
# ```
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'bo')
# plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
# plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
# plt.xticks(np.arange(0, 2, 0.2), labels=['Jan', '', 'Feb', '', 'Mar', '', 'May', '', 'June', '', 'July'])
# plt.yticks(np.arange(0, 7), ('0', '1GB', '2GB', '3GB', '4GB', '5GB', '6GB'))
#
# plt.show()
# ```

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
plt.xticks(np.arange(0, 2, 0.2), ['Jan', '', 'Feb', '', 'Mar', '', 'May', '', 'June', '', 'July'])
plt.yticks(np.arange(0, 7), ('0', '1GB', '2GB', '3GB', '4GB', '5GB', '6GB'))
# labels 파라미터를 사용하면 눈금 레이블을 문자열의 형태로 지정할 수 있습니다
# 입력해준 눈금의 개수와 같은 개수의 레이블을 지정해줍니다.

plt.show()

# %% [markdown]
# ### **| 눈금 스타일 설정하기**
#
#
#
# ```
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'bo')
# plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
# plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
# plt.xticks(np.arange(0, 2, 0.2), labels=['Jan', '', 'Feb', '', 'Mar', '', 'May', '', 'June', '', 'July'])
# plt.yticks(np.arange(0, 7), ('0', '1GB', '2GB', '3GB', '4GB', '5GB', '6GB'))
#
# plt.tick_params(axis='x', direction='in', length=3, pad=6, labelsize=14, labelcolor='green', top=True)
# plt.tick_params(axis='y', direction='inout', length=10, pad=15, labelsize=12, width=2, color='r')
#
# plt.show()
# ```

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
plt.xticks(np.arange(0,2,0.2), labels = ['Jan', '', 'Feb', '', 'Mar', '', 'May', '', 'June', '', 'July'])
plt.yticks(np.arange(0,7), ('0', '1GB', '2GB', '3GB', '4GB', '5GB', '6GB'))

# tick_params() 함수를 사용하면 눈금의 스타일을 다양하게 설정할 수 있습니다.
plt.tick_params(axis = 'x', direction = 'in', length = 3, pad = 6, labelsize = 14, labelcolor = 'green', top=True) 

plt.tick_params(axis='y', direction='inout', length=10, pad=15, labelsize=12, width=2, color='r')
# pad는 눈금과 레이블과의 거리를 지정합니다.
# top/bottom/left/right를 True/False로 지정하면 눈금이 표시될 위치를 선택할 수 있습니다.
plt.show()

# %% [markdown]
# ## **14. 타이틀 설정하기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92090/set_title_00.png width=450>
# </p>

# %% [markdown]
# ### **| 기본사용**
#
#
#
# ```
# import matplotlib.pyplot as plt
# import numpy as np
#
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'bo')
# plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
# plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
#
# plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
# plt.title('Graph Title')
#
# plt.show()
# ```

# %%
plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis = 'both', direction = 'in', length = 3, pad = 6, labelsize = 14)
plt.title('Graph Title')
# Out:
# Text(0.5, 1.0, 'Graph Title')

# %% [markdown]
# ### **| 위치와 오프셋 지정하기**
#
#
# ```
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'bo')
# plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
# plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
#
# plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
# plt.title('Graph Title', loc='right', pad=20)
#
# plt.show()
# ```

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
plt.title('Graph Title', loc='right', pad=20)

plt.show()

# plt.title() 함수의 loc 파라미터를 ‘right’로 설정하면, 타이틀이 그래프의 오른쪽 위에 나타나게 됩니다.
# {‘left’, ‘center’, ‘right’} 중 선택할 수 있으며 디폴트는 ‘center’입니다.
# pad 파라미터는 타이틀과 그래프와의 간격을 포인트 단위로 설정합니다.

# %% [markdown]
# ### **| 폰트 지정하기**
#
#
#
#
#
#
# ```
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'bo')
# plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
# plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
#
# plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
# plt.title('Graph Title', loc='right', pad=20)
#
# title_font = {
#     'fontsize': 16,
#     'fontweight': 'bold'
# }
# plt.title('Graph Title', fontdict=title_font, loc='left', pad=20)
#
# plt.show()
# ```

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
plt.title('Graph Title', loc='right', pad=20)

title_font = {
    'fontsize': 16,
    'fontweight': 'bold'
}
plt.title('Graph Title', fontdict = title_font, loc='left', pad=20)

plt.show()

# %% [markdown]
# ### **| 타이틀 얻기**
#
#
#
# ```
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'bo')
# plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
# plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
#
# plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
# title_right = plt.title('Graph Title', loc='right', pad=20)
#
# title_font = {
#     'fontsize': 16,
#     'fontweight': 'bold'
# }
# title_left = plt.title('Graph Title', fontdict=title_font, loc='left', pad=20)
#
# print(title_left.get_position())
# print(title_left.get_text())
#
# print(title_right.get_position())
# print(title_right.get_text())
#
# plt.show()
# ```

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
title_right = plt.title('Graph Title', loc='right', pad=20)

title_font = {
    'fontsize': 16,
    'fontweight': 'bold'
}
title_left = plt.title('Graph Title', fontdict=title_font, loc='left', pad=20)

print(title_left.get_position())
print(title_left.get_text())

print(title_right.get_position())
print(title_right.get_text())

plt.show()

# plt.title() 함수는 타이틀을 나타내는 Matplotlib text 객체를 반환합니다.
# get_position()과 get_text() 메서드를 사용해서 텍스트 위치와 문자열을 얻을 수 있습니다.
# Out:
# (0.0, 1.0)
# Graph Title
# (1.0, 1.0)
# Graph Title

# %% [markdown]
# ## **29. 이미지 저장하기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92090/set_title_00.png width=450>
# </p>

# %% [markdown]
# ### **| 기본사용**
#
#
#
# ```
# import numpy as np
# import matplotlib.pyplot as plt
#
# x1 = np.linspace(0.0, 5.0)
# x2 = np.linspace(0.0, 2.0)
#
# y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
# y2 = np.cos(2 * np.pi * x2)
#
# plt.subplot(2, 1, 1)                # nrows=2, ncols=1, index=1
# plt.plot(x1, y1, 'o-')
# plt.title('1st Graph')
# plt.ylabel('Damped oscillation')
#
# plt.subplot(2, 1, 2)                # nrows=2, ncols=1, index=2
# plt.plot(x2, y2, '.-')
# plt.title('2nd Graph')
# plt.xlabel('time (s)')
# plt.ylabel('Undamped')
#
# plt.tight_layout()
# # plt.show()
# plt.savefig('savefig_default.png')
# ```

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

plt.subplot(2, 1, 1)                # nrows=2, ncols=1, index=1
plt.plot(x1, y1, 'o-')
plt.title('1st Graph')
plt.ylabel('Damped oscillation')

plt.subplot(2, 1, 2)                # nrows=2, ncols=1, index=2
plt.plot(x2, y2, '.-')
plt.title('2nd Graph')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.tight_layout()
# plt.show()
plt.savefig('savefig_default.png')

# plt.savefig() 함수에 파일 이름을 입력해주면 아래와 같은 이미지 파일이 저장됩니다.

# %% [markdown]
# ## 문제풀이
# ---

# %% [markdown]
# ####**예제 01**
#
# 아래의 플롯과 최대한 비슷하게 그리고 `ch0201_01`로 저장하세요
#
#
# <p align='left'>
# <img src=https://github.com/yebiny/Lecture-EDA-basic/blob/main/imgs/07-1.PNG?raw=true width=400>
# </p>

# %%
x = [1,2,3,4,5]
p1 = [10,5,4,2,1]
p2 = [1,2,4,8,9]
plt.plot(x, p1, marker = 'o', linewidth = '2', markersize = '3')
plt.plot(x, p2, linewidth = '2', marker = 'o', markersize = '7')
plt.show()

# %% [markdown]
# ####**예제 02**
#
# 아래의 플롯과 최대한 비슷하게 그리고 `ch0201_02`로 저장하세요
#
# <p align='left'>
# <img src=https://github.com/yebiny/Lecture-EDA-basic/blob/main/imgs/07-2.PNG?raw=true width=400>
# </p>

# %%
x = [1,2,3,4,5]
p1 = [10,5,4,2,1]
p2 = [1,2,4,8,9]
plt.plot(x, p1, marker = 'o', label = 'Uncertainty')
plt.plot(x, p2, marker = 'o', label = 'Skill')
plt.fill_between(x[1:4], p1[1:4], p2[1:4], color = 'lightgreen', alpha = 0.5)
plt.legend(ncol = 2, frameon= True, shadow = True, loc = 'upper center', fontsize= 13)
plt.show()

# %% [markdown]
# ####**예제 03**
#
# 아래의 플롯과 최대한 비슷하게 그리고 `ch0201_03`로 저장하세요
#
#
# <p align='left'>
# <img src=https://github.com/yebiny/Lecture-EDA-basic/blob/main/imgs/07-3.PNG?raw=true width=400>
# </p>

# %%
x = [1,2,3,4,5]
p1 = [10,5,4,2,1]
p2 = [1,2,4,8,9]
plt.plot(x, p1, marker = 'o', label = 'Uncertainty')
plt.plot(x, p2, marker = 'o', label = 'Skill')
plt.axis([0,6,0,15])
plt.legend(ncol = 2, frameon= True, shadow = True, loc = 'upper center', fontsize= 14 )
plt.xlabel('X-Axis', color = 'c', fontweight = 'bold', fontdict = {'family':'serif', 'size': 16})
plt.ylabel('Y-Axis', color = 'c', fontweight = 'bold', fontdict = {'family':'serif', 'size': 16} )
plt.show()

# %% [markdown]
# ####**예제 04**
#
# 아래의 플롯과 최대한 비슷하게 그리고 `ch0201_04`로 저장하세요
#
# <p align='left'>
# <img src=https://github.com/yebiny/Lecture-EDA-basic/blob/main/imgs/07-4.PNG?raw=true width=400>
# </p>

# %%
x = [1,2,3,4,5]
p1 = [10,5,4,2,1]
p2 = [1,2,4,8,9]
plt.plot(x, p1, marker = 'o', label = 'Uncertainty', color = 'dodgerblue')
plt.plot(x, p2, marker = 'D', label = 'Skill', color = '#e377c2')
plt.legend(frameon= True, loc = 'upper center')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.grid()
plt.title('My plot', fontsize=16)
plt.show()

# %% [markdown]
# ####**예제 05**
#
# 아래의 플롯과 최대한 비슷하게 그리고 `ch0201_05`로 저장하세요
#
#
# <p align='left'>
# <img src=https://github.com/yebiny/Lecture-EDA-basic/blob/main/imgs/07-5.PNG?raw=true width=400>
# </p>

# %%
x = [1,2,3,4,5]
p1 = [10,5,4,2,1]
p2 = [1,2,4,8,9]
plt.plot(x, p1, '--', linewidth = 10 ,label = 'Uncertainty', color = 'dodgerblue')
plt.plot(x, p2, marker = '*', markersize = 18, linewidth = 5 , label = 'Skill', color = '#e377c2')
plt.legend(frameon= True, loc = 'upper center')
plt.xlabel('X-Axis', fontsize = 17)
plt.ylabel('Y-Axis', fontsize = 17)
plt.grid(axis = 'y')
plt.title('My plot', fontsize=18, loc = 'left', pad = 20)
plt.xticks(x)
plt.yticks(np.arange(2,11,2))
plt.tick_params(axis = 'both', direction= 'out', length= 10, width = 5, labelcolor = 'teal', labelsize = 15)
plt.show()

# %% [markdown]
# ####**예제 06**
#
# 본인 스타일 대로 데이터를 잘 나타내도록 그림을 그리고 `ch0201_06`으로 저장하세요.

# %%
x = [1,2,3,4,5]
p1 = [10,5,4,2,1]
p2 = [1,2,4,8,9]
plt.plot(x, p1, marker = 'o', markersize= 4, label = 'Uncertainty', color = 'dodgerblue')
plt.plot(x, p2, marker = 'x', label = 'Skill', color = 'navy')
plt.legend(frameon= True, loc = 'best')
plt.xlabel('X-Axis', fontsize = 12)
plt.ylabel('Y-Axis', fontsize = 12)
plt.grid(axis = 'y')
plt.title('My plot', fontsize=17, loc = 'center', pad = 15)
plt.xticks(x)
plt.yticks(np.arange(2,11,2))
plt.tick_params(axis = 'both', direction= 'inout', length= 8)
plt.tight_layout()
# plt.show()
plt.savefig('ch0201_06.png')
