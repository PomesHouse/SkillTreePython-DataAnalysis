# %% [markdown]
# <a href="https://colab.research.google.com/github/PomesHouse/SkillTreePython-DataAnalysis/blob/main/01.%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D%EA%B8%B0%EC%B4%88/06_Pandas_%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%9D%BD%EA%B3%A0%EC%A0%80%EC%9E%A5%ED%95%98%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ch06. Pandas - 데이터읽고 저장하기
# ---
# * 날짜:
# * 이름:

# %% [markdown]
# ## 개념정리
# ---

# %% [markdown]
# ```
# import pandas as pd
# ```

# %%
import pandas as pd

# %% [markdown]
# ---
# ### **(1) 데이터 불러오기**
# ---
#
#
# `read_csv` 함수는 테이블 형태의 데이터를 불러오는데 효과적으로 사용됩니다.
#
# * `pd.read_csv(filepath, sep, header, index_col, usecols, parse_dates, nrows)`
#   * `filepath`: 파일 경로 및 이름
#   * `sep`: 구분자 (디폴트 ',')
#   * `header`: 헤더의 위치, None일 경우 0, 1, 2, .. 자동 부여
#   * `index_col` : 인덱스의 위치 (디폴트 None)
#   * `usecols`: 사용할 컬럼 및 위치 목록
#   * `nrows`: 불러올 행의 개수

# %% [markdown]
# #### **| 텍스트 파일 불러오기**

# %% [markdown]
# 우선 텍스트 파일을 하나 생성하겠습니다.
#
#
# ```
# with open('test.txt', 'w') as f:
#   for i in range(5):
#     f.write(f'{i} , {i+1} , {i+2}\n')
# ```

# %%
with open('test.txt', 'w') as f:
  for i in range(5):
    f.write(f'{i} , {i+1} , {i+2}\n')

# %% [markdown]
# 생성한 텍스트 파일을 `read_csv`를 이용해 불러옵니다.
#
# ```
# df_test = pd.read_csv('test.txt')
# df_test
# ```

# %%
df_test = pd.read_csv('test.txt')
df_test
# Out:
#    0    1    2
# 0   1    2   3
# 1   2    3   4
# 2   3    4   5
# 3   4    5   6

# %% [markdown]
# 이번엔 텍스트 파일의 구분을 탭(`\t`)이용해 작성합니다.
#
#
# ```
# with open('test.txt', 'w') as f:
#   for i in range(5):
#     f.write(f'{i} \t {i+1} \t {i+2}\n')
# ```

# %%
with open('test.txt', 'w') as f:
  for i in range(5):
    f.write(f'{i} \t {i+1} \t {i+2}\n')

# %% [markdown]
# 똑같이 텍스트 파일을 불러옵니다.
#
# ```
# df_test = pd.read_csv('test.txt')
# df_test
# ```

# %%
df_test = pd.read_csv('test.txt')
df_test
# Out:
#    0 \t 1 \t 2
# 0  1 \t 2 \t 3
# 1  2 \t 3 \t 4
# 2  3 \t 4 \t 5
# 3  4 \t 5 \t 6

# %% [markdown]
# `read_csv`는 데이터를 불러올 때 구분자 디폴트가 콤마(,) 입니다.
#
# 따라서 탭을 이용한 경우는 옵션을 설정해 줍니다.
#
# ```
# df_test = pd.read_csv('test.txt', sep='\t')
# df_test
# ```

# %%
df_test = pd.read_csv('test.txt', sep='\t')
df_test
# Out:
#    0    1    2
# 0   1    2   3
# 1   2    3   4
# 2   3    4   5
# 3   4    5   6

# %% [markdown]
# 이 때 각 열의 이름이 첫번 째 줄로 자동 저장 됩니다. 이를 방지하려면 `header`를 `None`으로 설정해야 합니다.
#
# ```
# df_test = pd.read_csv('test.txt', sep='\t', header=None)
# df_test
# ```

# %%
df_test = pd.read_csv('test.txt', sep='\t', header=None)
df_test
# Out:
#    0  1  2
# 0  0  1  2
# 1  1  2  3
# 2  2  3  4
# 3  3  4  5
# 4  4  5  6

# %% [markdown]
# #### **| CSV 파일 불러오기**
#
# 이번에는 `csv`파일을 불러옵니다.
#
# ```
# f_path = '/content/sample_data/california_housing_test.csv'
# df = pd.read_csv(f_path)
# df
# ```

# %%
f_path = '/content/sample_data/california_housing_test.csv'
df = pd.read_csv(f_path)
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %% [markdown]
# #### **| 제한적으로 불러오기**
#
# ```
# df_short = pd.read_csv(f_path,
#                  usecols = [2, 3, 5],
#                  nrows = 1000)
#
# df_short
# ```

# %%
df_short = pd.read_csv(f_path,
                 usecols = [2, 3, 5], 
                 nrows = 1000)

df_short
# Out:
#      housing_median_age  total_rooms  population
# 0                  27.0       3885.0      1537.0
# 1                  43.0       1510.0       809.0
# 2                  27.0       3589.0      1484.0
# 3                  28.0         67.0        49.0
# 4                  19.0       1241.0       850.0
# ..                  ...          ...         ...
# 995                15.0       1472.0       892.0
# 996                35.0       1789.0       897.0
# 997                39.0        308.0        59.0
# 998                48.0       1601.0       784.0
# 999                29.0       3403.0      3432.0
#
# [1000 rows x 3 columns]

# %% [markdown]
# ---
# ### **(2) 데이터 출력**
# ---

# %% [markdown]
# option을 이용해서 최대 행의 개수와 최소 열의 개수를 조정할 수 있습니다.
#
# ```
# pd.set_option('display.max_rows', None)
# # 최대 행의 개수 조정
# pd.set_option('display.max_columns', None)
# # 최대 열의 개수 조정
# ```

# %%
pd.set_option('display.max_columns', None)

# %%
df_short

# %% [markdown]
# #### **| 출력 함수**

# %% [markdown]
# * `.head(n)` 가장 처음 데이터 n줄만 보여줍니다. (n을 정의하지 않으면 n=5)

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %% [markdown]
# * `.tail(n)` 가장 마지막 데이터 n줄만 보여줍니다. (n을 정의하지 않으면 n=5)

# %%
df.tail(3)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %% [markdown]
# * `.columns` : 열의 인덱스를 반환합니다.

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %% [markdown]
# #### **| 기본 정보**
#
# * `.shape` : 데이터의 shape 를 출력합니다.
# * `.dtypes` : 데이터의 타입을 확인합니다.
# * `.info()` : 데이터에 대한 개략적인 정보를 표시합니다.
# * `.describe()` : 각 column 들의 기술 통계량을 출력합니다.
#   * `count`: 해당 column에서 비어 있지 않은 값의 개수
#   * `mean`: 평균
#   * `std`: 표준편차
#   * `min`: 최솟값 (이상치 포함)
#   * `25%` (Q1): 전체 데이터를 순서대로 정렬했을 때, 아래에서 부터 1/4번째 지점에 있는 값
#   * `50%` (Q2): 중앙값 (전체 데이터를 순서대로 정렬했을 때, 아래에서 부터 2/4번째 지점에 있는 값)
#   * `75%` (Q3): 전체 데이터를 순서대로 정렬했을 때, 아래에서 부터 3/4번째 지점에 있는 값
#   * `max`: 최댓값 (이상치 포함)
#
# * `.corr()`: 변수들 간 상관관계를 출력합니다.
# * `.isnull()` : 결측치가 있는지를 출력합니다.

# %%
df.shape
# Out:
# (3000, 9)

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
df.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# 25%        291.000000    780.000000   273.00000       2.544000
# 50%        437.000000   1155.000000   409.50000       3.487150
# 75%        636.000000   1742.750000   597.25000       4.656475
# max       5419.000000  11935.000000  4930.00000      15.000100
#
#        median_house_value
# count          3000.00000
# mean         205846.27500
# std          113119.68747
# min           22500.00000
# 25%          121200.00000
# 50%          177650.00000
# 75%          263975.00000
# max          500001.00000

# %%
df.corr()

# %%
df.isnull()

# %% [markdown]
# #### **|  값 카운팅**
#
# 데이터의 카운팅은 보통 연속형 자료가 아닌 범주형 자료에 사용됨을 참고하세요.
#
# 데이터 전체에 대해 카운팅을 할 수 있지만 보통 범주형 자료형에 대해서만 카운팅을 하기 때문에 특정 열에만 접근 할 필요가 있습니다.
#
# 특정 열에 접근하는 방법은 몇가지가 있지만 이번시간에는 간단히 `df.열이름`을 이용해 보겠습니다.
#
# ```
# df.total_bedrooms
# ```

# %%
df.total_bedrooms.head()
# Out:
# 0    661.0
# 1    310.0
# 2    507.0
# 3     15.0
# 4    244.0
# Name: total_bedrooms, dtype: float64

# %% [markdown]
# * `.value_counts()` : 데이터의 개수를 카운트 합니다.
#
# ```
# df.total_bedrooms.value_counts()
# ```

# %%
df.total_bedrooms.value_counts()

# %% [markdown]
# * `.unique()` : 데이터의 모든 값을 (중복제거하여) 출력합니다.
#
# ```
# df.total_bedrooms.unique()
# ```

# %%
df.total_bedrooms.unique()
# Out:
# array([ 661.,  310.,  507., ...,  779., 1037.,  743.])

# %% [markdown]
# #### **| 집계함수**
#
#
# |함수 | 내용|
# |--|--|
# |sum | 합계|
# |mean|평균|
# |std|표준편차|
# |var|분산|
# |quantile|백분위수|
# |min|최소값|
# |max|최대값|

# %%
df.total_rooms.std()
# Out:
# 2155.59333162558

# %% [markdown]
# * `quantile(n)`: 상위 `n`프로의 값을 얻습니다
#
# ```
# print(df.total_rooms.quantile(0.1)) # 상위 10%
# print(df.total_rooms.quantile(0.5)) # 중앙값
# print(df.total_rooms.median()) # 중앙값
# ```

# %%
print(df.total_rooms.quantile(0.1)) # 상위 10%
print(df.total_rooms.quantile(0.5)) # 중앙값
print(df.total_rooms.median()) # 중앙값
# Out:
# 907.9000000000001
# 2106.0
# 2106.0

# %% [markdown]
# ---
# ### **(3) 데이터 통합**
# ---

# %% [markdown]
# #### **| `concat` 이용하기**
#
# * `pandas.concat([])`
#   * 둘 이상의 데이터 프레임을 이어 붙이는데 사용
#   * 주요입력
#     * `objs`: DataFrame을 요소로 하는 리스트로 입력 순서대로 병합됨.
#     * `ignore_index`: `True`면 기존 인덱스 무시하고 새로운 인덱스 부여, `False`면 기존 인덱스를 사용
#     * 보통 행단위는 `ignore_index`를 `True`, 열단위는 `False`
#     * `axis` : 0이면 행 단위로 병합 수행, 1이면 열단위로 병합 수행

# %% [markdown]
# 전체 데이터에서 `longitude`, `latitude`열만 불러옵니다.
#
# ```
# df1 = pd.read_csv(f_path,
#                  usecols = [0, 1],
#                  nrows = 5)
#
# df1
# ```

# %%
df1 = pd.read_csv(f_path,
                 usecols = [0, 1], 
                 nrows = 5)

df1
# Out:
#    longitude  latitude
# 0    -122.05     37.37
# 1    -118.30     34.26
# 2    -117.81     33.78
# 3    -118.36     33.82
# 4    -119.67     36.33

# %% [markdown]
# 전체 데이터에서 `total_rooms`, `total_bedrooms`열만 불러옵니다.
#
# ```
# df2 = pd.read_csv(f_path,
#                  usecols = [3, 4],
#                  nrows = 5)
#
# df2
# ```

# %%
df2 = pd.read_csv(f_path,
                 usecols = [3, 4], 
                 nrows = 5)

df2
# Out:
#    total_rooms  total_bedrooms
# 0       3885.0           661.0
# 1       1510.0           310.0
# 2       3589.0           507.0
# 3         67.0            15.0
# 4       1241.0           244.0

# %% [markdown]
# `.concat` 을 이용해 상하(axis=0)로 결합합니다.
#
# ```
# df_concat = pd.concat([df1, df1], axis=0, ignore_index=True)
# df_concat
# ```

# %%
df_concat = pd.concat([df1, df1], axis=0, ignore_index=True) 
# ignore_index = False로 하면 / columns이 같기때문에 밑에 잘 붙으나, 인덱스가 다시 0부터 시작한다. 
df_concat

# %% [markdown]
# `.concat` 을 이용해 좌우(axis=1)로 결합합니다.
#
# ```
# df_concat = pd.concat([df1, df2], axis=1)
# df_concat
# ```

# %%
df_concat = pd.concat([df1, df2], axis=1)
df_concat
# Out:
#    longitude  latitude  total_rooms  total_bedrooms
# 0    -122.05     37.37       3885.0           661.0
# 1    -118.30     34.26       1510.0           310.0
# 2    -117.81     33.78       3589.0           507.0
# 3    -118.36     33.82         67.0            15.0
# 4    -119.67     36.33       1241.0           244.0

# %%
df_concat = pd.concat([df1, df2], axis=0, ignore_index=True) 
# ignore_index를 False로 하나 True로 하나 새 columns가 붙는 것은 사실이고 
# df1 밑에 붙으나
# ignore_index = False인 경우 인덱싱이 다시 0부터 시작된다.
# 빈칸은 NaN처리. 
df_concat
# Out:
#    longitude  latitude  total_rooms  total_bedrooms
# 0    -122.05     37.37          NaN             NaN
# 1    -118.30     34.26          NaN             NaN
# 2    -117.81     33.78          NaN             NaN
# 3    -118.36     33.82          NaN             NaN
# 4    -119.67     36.33          NaN             NaN
# 5        NaN       NaN       3885.0           661.0
# 6        NaN       NaN       1510.0           310.0
# 7        NaN       NaN       3589.0           507.0
# 8        NaN       NaN         67.0            15.0
# 9        NaN       NaN       1241.0           244.0

# %% [markdown]
# #### **| `merge` 이용하기**
#
#
# * `pandas.merge`
#   * key 변수를 기준으로 두개의 데이터 프레임을 병합(join)하는 함수.
#   * 주요 입력
#     * `left`: 통합 대상 데이터 프레임1
#     * `right`: 통합
#     * `on` : 통합기준 key 변수 및 변수 리스트 (입력을 하지 않으면 이름이 같은 변수를 key로 식별)
#     * `left_on` : 데이터프레임1의 key 변수 및 변수 리스트
#     * `right_on`: 데이터프레임2의 key 변수 및 변수 리스트
#     * `left_index`: 데이터프레임1의 인덱스를 key 변수로 사용할 것인지 여부
#     * `left_index`: 데이터프레임1의 인덱스를 key 변수로 사용할 것인지 여부

# %% [markdown]
# 전체 데이터에서 `longitude`, `total_rooms`, `total_bedrooms`열만 불러옵니다.
#
# ```
# df3 = pd.read_csv(f_path,
#                  usecols = [0, 3, 4],
#                  nrows = 5)
#
# df3
# ```

# %%
df3 = pd.read_csv(f_path,
                 usecols = [0, 3, 4], 
                 nrows = 5)

df3
# Out:
#    longitude  total_rooms  total_bedrooms
# 0    -122.05       3885.0           661.0
# 1    -118.30       1510.0           310.0
# 2    -117.81       3589.0           507.0
# 3    -118.36         67.0            15.0
# 4    -119.67       1241.0           244.0

# %% [markdown]
# 두 데이터를 `merge` 합니다.
# ```
# df_merge = pd.merge(df1, df3)
# df_merge
# ```

# %%
df_merge = pd.merge(df1, df3)
df_merge
# Out:
#    longitude  latitude  total_rooms  total_bedrooms
# 0    -122.05     37.37       3885.0           661.0
# 1    -118.30     34.26       1510.0           310.0
# 2    -117.81     33.78       3589.0           507.0
# 3    -118.36     33.82         67.0            15.0
# 4    -119.67     36.33       1241.0           244.0

# %% [markdown]
# ---
# ### **(4) 데이터 저장하기**
# ---
#
#
# * `.to_csv(savepath, index)`
#   * `filepath` : 파일 경로 및 이름
#   * `index` : 인덱스 저장여부 (bool)
#
#
# ```
# df_merge.to_csv("ch06_merged.csv", index = True)
# ```

# %%
df_merge.to_csv("ch06_merged.csv", index = True)

# %% [markdown]
# ## 문제풀이
# ---

# %% [markdown]
# **예제 01**
#
# `sample_data/california_housing_test.csv` 에서 열 `population`   `households`    `median_income` 만 위에서 500줄 불러오고 `df01`로 바인딩 하세요.

# %%
df01 = pd.read_csv('sample_data/california_housing_test.csv', 
                   usecols = ['population', 'households', 'median_income'],
                   nrows = 500)
df01.head()
# Out:
#    population  households  median_income
# 0      1537.0       606.0         6.6085
# 1       809.0       277.0         3.5990
# 2      1484.0       495.0         5.7934
# 3        49.0        11.0         6.1359
# 4       850.0       237.0         2.9375

# %% [markdown]
# **예제 02**
#
# `sample_data/california_housing_test.csv` 에서 열 `median_income`   `median_house_value` 만 위에서 500줄 불러오고 `df02`로 바인딩 하세요.

# %%
df02 = pd.read_csv('sample_data/california_housing_test.csv', 
                usecols = ['median_income', 'median_house_value'],
                nrows = 500)
df02.head()
# Out:
#    median_income  median_house_value
# 0         6.6085            344700.0
# 1         3.5990            176500.0
# 2         5.7934            270500.0
# 3         6.1359            330000.0
# 4         2.9375             81700.0

# %% [markdown]
# **예제 03**
#
# `df02`의 `.describe`를 실행하고 이를 통해 알 수 있는 정보를 정리하세요.

# %%
df02.describe() 
# 500개의 value가 있고 mean은 3.79 정도 된다. 
# 최소와 최대값은 각각 0.50, 15.00이며
# std는 1.88이다.
# Out:
#        median_income  median_house_value
# count     500.000000          500.000000
# mean        3.790603       201901.242000
# std         1.884643       109422.391852
# min         0.499900        44400.000000
# 25%         2.569150       121450.000000
# 50%         3.408350       175050.000000
# 75%         4.562500       258575.000000
# max        15.000100       500001.000000

# %% [markdown]
# **예제 04**
#
# `df01`과 `df02`를 `concat`을 이용해 좌우로 연결하세요. 데이터가 어떻게 합쳐지는지 간단히 설명하세요.

# %%
pd.concat([df01, df02], axis = 1).head()
# 같은 이름의 column이 있어도 각각이 유지된채로 이어붙여진다.
# Out:
#    population  households  median_income  median_income  median_house_value
# 0      1537.0       606.0         6.6085         6.6085            344700.0
# 1       809.0       277.0         3.5990         3.5990            176500.0
# 2      1484.0       495.0         5.7934         5.7934            270500.0
# 3        49.0        11.0         6.1359         6.1359            330000.0
# 4       850.0       237.0         2.9375         2.9375             81700.0

# %% [markdown]
# **예제 05**
#
# `df01`과 `df02`를 `merge`을 이용해 좌우로 연결하세요. 데이터가 어떻게 합쳐지는지 간단히 설명하세요.

# %%
pd.merge(df01,df02).head()
# 같은 이름의 column 기준으로 겹쳐 붙여졌다.
# Out:
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
pd.merge(df01,df02).head()
# Out:
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0
